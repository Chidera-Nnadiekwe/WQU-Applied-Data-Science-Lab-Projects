# %%
# %pip install category-encoders
# Out:
# Collecting category-encoders
#   Downloading category_encoders-2.9.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\churc\anaconda3\lib\site-packages (from category-encoders) (2.3.4)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\churc\anaconda3\lib\site-packages (from category-encoders) (2.3.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\churc\anaconda3\lib\site-packages (from category-encoders) (1.0.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\churc\anaconda3\lib\site-packages (from category-encoders) (1.7.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\churc\anaconda3\lib\site-packages (from category-encoders) (1.16.3)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\churc\anaconda3\lib\site-packages (from category-encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\churc\anaconda3\lib\site-packages (from pandas>=1.0.5->category-encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\churc\anaconda3\lib\site-packages (from pandas>=1.0.5->category-encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\churc\anaconda3\lib\site-packages (from pandas>=1.0.5->category-encoders) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\churc\anaconda3\lib\site-packages (from scikit-learn>=1.6.0->category-encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\churc\anaconda3\lib\site-packages (from scikit-learn>=1.6.0->category-encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\churc\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category-encoders) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\churc\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category-encoders) (1.16.0)
# Downloading category_encoders-2.9.0-py3-none-any.whl (85 kB)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import libraries here
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from glob import glob
from category_encoders import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.pipeline import make_pipeline

warnings.simplefilter(action="ignore", category=FutureWarning)
